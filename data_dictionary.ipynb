# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# | Feature | Source: Orig or Calc | Feature Description | dtype | Category: Alpha or Numeric |
# | :--- | :---: | :--- | :---: | :---: |
# | **airconditioningdesc** | **orig** | Type of cooling system present in the home (if any) | category | alpha |
# | **airconditioningtypeid** | **orig** | Type of cooling system present in the home (if any) | category | numeric |
# | **architecturalstyledesc** | **orig** | Architectural style of the home (i.e. ranch, colonial, split-level, etc…) | category | alpha |
# | **architecturalstyletypeid** | **orig** | Architectural style of the home (i.e. ranch, colonial, split-level, etc…) | category | numeric |
# | **assessmentyear** | **orig** | The year of the property tax assessment | int64 |  |
# | **basementsqft** | **orig** | Finished living area below or partially below ground level | int64 |  |
# | **bathroomcnt** | **orig** | Number of bathrooms in home including fractional bathrooms | float64 |  |
# | **bedroomcnt** | **orig** | Number of bedrooms in home | int64 |  |
# | **buildingclassdesc** | **orig** | The building framing type (steel frame, wood frame, concrete/brick) | category | alpha |
# | **buildingclasstypeid** | **orig** | The building framing type (steel frame, wood frame, concrete/brick) | category | numeric |
# | **buildingqualitytypeid** | **orig** | Overall assessment of condition of the building from best (lowest) to worst (highest) | category | numeric |
# | **calculatedbathnbr** | **orig** | Number of bathrooms in home including fractional bathroom | float64 |  |
# | **calculatedfinishedsquarefeet** | **orig** | Calculated total finished living area of the home | int64 |  |
# | **censustractandblock** | **orig** | Census tract and block ID combined - also contains blockgroup assignment by extension | category | numeric |
# | **county** | **orig** | Name of county in which the property is located | category | alpha |
# | **decktypeid** | **orig** | Type of deck (if any) present on parcel | category | numeric |
# | **finishedfloor1squarefeet** | **orig** | Size of the finished living area on the first (entry) floor of the home | int64 |  |
# | **finishedsquarefeet12** | **orig** | Finished living area | int64 |  |
# | **finishedsquarefeet13** | **orig** | Perimeter living area | int64 |  |
# | **finishedsquarefeet15** | **orig** | Total area | int64 |  |
# | **finishedsquarefeet50** | **orig** | Size of the finished living area on the first (entry) floor of the home | int64 |  |
# | **finishedsquarefeet6** | **orig** | Base unfinished and finished area | int64 |  |
# | **fips** | **orig** | Federal Information Processing Standard code - see https://en.wikipedia.org/wiki/FIPS_county_code for more details | category | numeric |
# | **fireplacecnt** | **orig** | Number of fireplaces in a home (if any) | int64 |  |
# | **fireplaceflag** | **orig** | Is a fireplace present in this home | bool |  |
# | **fullbathcnt** | **orig** | Number of full bathrooms (sink, shower + bathtub, and toilet) present in home | int64 |  |
# | **garagecarcnt** | **orig** | Total number of garages on the lot including an attached garage | int64 |  |
# | **garagetotalsqft** | **orig** | Total number of square feet of all garages on lot including an attached garage | int64 |  |
# | **hashottuborspa** | **orig** | Does the home have a hot tub or spa | int64 |  |
# | **heatingorsystemdesc** | **orig** | Type of home heating system | category | alpha |
# | **heatingorsystemtypeid** | **orig** | Type of home heating system | category | numeric |
# | **landtaxvaluedollarcnt** | **orig** | The assessed value of the land area of the parcel | int64 |  |
# | **latitude** | **orig** | Latitude of the middle of the parcel multiplied by 10e6 | float64 |  |
# | **longitude** | **orig** | Longitude of the middle of the parcel multiplied by 10e6 | float64 |  |
# | **lotsizesquarefeet** | **orig** | Area of the lot in square feet | int64 |  |
# | **numberofstories** | **orig** | Number of stories or levels the home has | int64 |  |
# | **parcelid** | **orig** | Unique identifier for parcels (lots) | int64 |  |
# | **poolcnt** | **orig** | Number of pools on the lot (if any) | int64 |  |
# | **poolsizesum** | **orig** | Total square footage of all pools on property | int64 |  |
# | **pooltypeid10** | **orig** | Spa or Hot Tub | int64 |  |
# | **pooltypeid2** | **orig** | Pool with Spa/Hot Tub | int64 |  |
# | **pooltypeid7** | **orig** | Pool without hot tub | int64 |  |
# | **propertycountylandusecode** | **orig** | County land use code i.e. it's zoning at the county level | category | alpha |
# | **propertylandusedesc** | **orig** | Type of land use the property is zoned for | category | alpha |
# | **propertylandusetypeid** | **orig** | Type of land use the property is zoned for | category | numeric |
# | **propertyzoningdesc** | **orig** | Description of the allowed land uses (zoning) for that property | category | alpha |
# | **rawcensustractandblock** | **orig** | Census tract and block ID combined - also contains blockgroup assignment by extension | category | numeric |
# | **regionidcity** | **orig** | City in which the property is located (if any) | category | numeric |
# | **regionidcounty** | **orig** | County in which the property is located | category | numeric |
# | **regionidneighborhood** | **orig** | Neighborhood in which the property is located | category | numeric |
# | **regionidzip** | **orig** | Zip code in which the property is located | category | numeric |
# | **roomcnt** | **orig** | Total number of rooms in the principal residence | int64 |  |
# | **state** | **orig** | Name of state in which the property is located | category | alpha |
# | **storydesc** | **orig** | Type of floors in a multi-story house (i.e. basement and main level, split-level, attic, etc.). See tab for details. | category | alpha |
# | **storytypeid** | **orig** | Type of floors in a multi-story house (i.e. basement and main level, split-level, attic, etc.). See tab for details. | category | numeric |
# | **structuretaxvaluedollarcnt** | **orig** | The assessed value of the built structure on the parcel | int64 |  |
# | **taxamount** | **orig** | The total property tax assessed for that assessment year | float64 |  |
# | **taxdelinquencyflag** | **orig** | Property taxes for this parcel are past due as of 2015 | bool |  |
# | **taxdelinquencyyear** | **orig** | Year for which the unpaid propert taxes were due | int64 |  |
# | **taxvaluedollarcnt** | **orig** | The total tax assessed value of the parcel | int64 |  |
# | **threequarterbathnbr** | **orig** | Number of 3/4 bathrooms in house (shower + sink + toilet) | int64 |  |
# | **typeconstructiondesc** | **orig** | What type of construction material was used to construct the home | category | alpha |
# | **typeconstructiontypeid** | **orig** | What type of construction material was used to construct the home | category | numeric |
# | **unitcnt** | **orig** | Number of units the structure is built into (i.e. 2 = duplex, 3 = triplex, etc...) | int64 |  |
# | **yardbuildingsqft17** | **orig** | Patio in yard | int64 |  |
# | **yardbuildingsqft26** | **orig** | Storage shed/building in yard | int64 |  |
# | **yearbuilt** | **orig** | The Year the principal residence was built | int64 |  |
# | **cluster** | **calc** | Cluster to which property is assigned in clustering algorithm | category | numeric |
# | **dtr_pred** | **calc** | Decistion Tree Regressor prediction of target variable | float64 |  |
# | **sdpsf_score** | **calc** | Scaled structuredollarpersqft * multiplier used for weighted clustering | float64 |  |
# | **structuredollarpersqft** | **calc** | Structure dollar value per calculated finished square foot | float64 |  |
# | **y** | **calc** | Target variable | float64 |  |
# | **yhat** | **calc** | Target variable mean | float64 |  |![image.png](attachment:image.png)
